# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
import pandas as pd
import numpy as np
import matplotlib.pyplot
import matplotlib.pyplot as plt
import seaborn as sb
low_memory=False
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,10)
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90
# Out:
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mauro/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
filename = 'Modelo03_1979_2015.csv'
df = pd.read_csv(filename,sep=',')

# %%
df.shape
# Out:
# (16, 7)

# %%
df.describe()
# Out:
#               FAIXA_ETARIA OBITOS_HOMES TAXA_ESPECIFICA_HOMES OBITOS_MULHERES  \
# count                   16           16                    16              16
# unique                  16           14                    15              14
# top     Taxa Padrao Brasil            -                  0.01               -
# freq                     1            3                     2               3
#
#        TAXA_ESPECIFICA_MULHERES OBITOS_TODOS TAXA_ESPECIFICA_TODOS
# count                        16           16                    16
# unique                       14           14                    15
# top                        0.01            -                  0.01
# freq                          3            3                     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FAIXA_ETARIA              16 non-null     object
#  1   OBITOS_HOMES              16 non-null     object
#  2   TAXA_ESPECIFICA_HOMES     16 non-null     object
#  3   OBITOS_MULHERES           16 non-null     object
#  4   TAXA_ESPECIFICA_MULHERES  16 non-null     object
#  5   OBITOS_TODOS              16 non-null     object
#  6   TAXA_ESPECIFICA_TODOS     16 non-null     object
# dtypes: object(7)
# memory usage: 1.0+ KB

# %%
df['OBITOS_HOMES'] = df['OBITOS_HOMES'].apply(pd.to_numeric, errors='coerce').abs()
df['OBITOS_MULHERES'] = df['OBITOS_MULHERES'].apply(pd.to_numeric, errors='coerce').abs()
df['OBITOS_TODOS'] = df['OBITOS_TODOS'].apply(pd.to_numeric, errors='coerce').abs()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   FAIXA_ETARIA              16 non-null     object
#  1   OBITOS_HOMES              13 non-null     float64
#  2   TAXA_ESPECIFICA_HOMES     16 non-null     object
#  3   OBITOS_MULHERES           13 non-null     float64
#  4   TAXA_ESPECIFICA_MULHERES  16 non-null     object
#  5   OBITOS_TODOS              13 non-null     float64
#  6   TAXA_ESPECIFICA_TODOS     16 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 1.0+ KB

# %%
df.head(16)
# Out:
#            FAIXA_ETARIA  OBITOS_HOMES TAXA_ESPECIFICA_HOMES  OBITOS_MULHERES  \
# 0               00 a 04          38.0                  0.01             22.0
# 1               05 a 09          25.0                  0.01             17.0
# 2               10 a 14          80.0                  0.03             44.0
# 3               15 a 19         284.0                  0.09            186.0
# 4               20 a 29        1920.0                  0.37           1770.0
# 5               30 a 39        5205.0                  1.25           5823.0
# 6               40 a 49       11685.0                  3.71          13687.0
# 7               50 a 59       23589.0                 11.04          24472.0
# 8               60 a 69       35420.0                 26.53          34177.0
# 9               70 a 79       36755.0                 54.34          39455.0
# 10           80 ou mais       21522.0                 88.91          33118.0
# 11       Idade ignorada         145.0                  8.54            176.0
# 12                Total      136668.0                     -         152947.0
# 13           Taxa Bruta           NaN                  4.67              NaN
# 14  Taxa Padrao Mundial           NaN                  6.04              NaN
# 15   Taxa Padrao Brasil           NaN                  6.56              NaN
#
#    TAXA_ESPECIFICA_MULHERES  OBITOS_TODOS TAXA_ESPECIFICA_TODOS
# 0                      0.01          61.0                  0.01
# 1                      0.01          42.0                  0.01
# 2                      0.01         124.0                  0.02
# 3                      0.06         470.0                  0.08
# 4                      0.33        3693.0                  0.35
# 5                      1.33       11032.0                  1.29
# 6                      4.13       25383.0                  3.92
# 7                     10.61       48073.0                 10.82
# 8                     22.53       69623.0                 24.41
# 9                     47.19       76239.0                 50.41
# 10                    90.69       54650.0                 89.99
# 11                    10.16         327.0                  9.53
# 12                        -      289717.0                     -
# 13                     5.08           NaN                  4.88
# 14                     5.57           NaN                  5.79
# 15                     6.13           NaN                  6.33

# %%
df.drop('TAXA_ESPECIFICA_HOMES', axis=1,inplace=True)
df.drop('TAXA_ESPECIFICA_MULHERES', axis=1,inplace=True)
df.drop('TAXA_ESPECIFICA_TODOS', axis=1,inplace=True)
df = df.dropna()

# %%
df.head()
# Out:
#   FAIXA_ETARIA  OBITOS_HOMES  OBITOS_MULHERES  OBITOS_TODOS
# 0      00 a 04          38.0             22.0          61.0
# 1      05 a 09          25.0             17.0          42.0
# 2      10 a 14          80.0             44.0         124.0
# 3      15 a 19         284.0            186.0         470.0
# 4      20 a 29        1920.0           1770.0        3693.0

# %%
df.head(16)
# Out:
#       FAIXA_ETARIA  OBITOS_HOMES  OBITOS_MULHERES  OBITOS_TODOS
# 0          00 a 04          38.0             22.0          61.0
# 1          05 a 09          25.0             17.0          42.0
# 2          10 a 14          80.0             44.0         124.0
# 3          15 a 19         284.0            186.0         470.0
# 4          20 a 29        1920.0           1770.0        3693.0
# 5          30 a 39        5205.0           5823.0       11032.0
# 6          40 a 49       11685.0          13687.0       25383.0
# 7          50 a 59       23589.0          24472.0       48073.0
# 8          60 a 69       35420.0          34177.0       69623.0
# 9          70 a 79       36755.0          39455.0       76239.0
# 10      80 ou mais       21522.0          33118.0       54650.0
# 11  Idade ignorada         145.0            176.0         327.0
# 12           Total      136668.0         152947.0      289717.0

# %%
df.plot.bar(x = 'FAIXA_ETARIA')
# Out:
# <AxesSubplot:xlabel='FAIXA_ETARIA'>

# %%
df.plot.bar(x = 'FAIXA_ETARIA', figsize=(11, 8), fontsize = 10)
# Out:
# <AxesSubplot:xlabel='FAIXA_ETARIA'>
